# %% [markdown]
# # **Data Collecting (Data Collection)**

# %%
import pandas as pd
import numpy as np

# Raw data (intentionally includes missing & wrong values)
data = {
    "Student": ["Rohit", "Amit", "Sneha", "Pooja", "Rahul"],
    "Maths": [78, 85, np.nan, 66, 72],
    "Science": [82, 88, 94, None, 76],
    "English": [75, 80, 85, 68, None]
}

df = pd.DataFrame(data)
df
# Out:
#   Student  Maths  Science  English
# 0   Rohit   78.0     82.0     75.0
# 1    Amit   85.0     88.0     80.0
# 2   Sneha    NaN     94.0     85.0
# 3   Pooja   66.0      NaN     68.0
# 4   Rahul   72.0     76.0      NaN

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# Check Missing Values

# %%
df.isnull()
# Out:
#    Student  Maths  Science  English
# 0    False  False    False    False
# 1    False  False    False    False
# 2    False   True    False    False
# 3    False  False     True    False
# 4    False  False    False     True

# %%
df.isnull().sum()
# Out:
# Student    0
# Maths      1
# Science    1
# English    1
# dtype: int64

# %% [markdown]
# Fill Missing Values (Cleaning)

# %%
df["Maths"].fillna(df["Maths"].mean(), inplace=True)
df["Science"].fillna(df["Science"].mean(), inplace=True)
df["English"].fillna(df["English"].mean(), inplace=True)

df
# Out:
# /tmp/ipython-input-3432938247.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Maths"].fillna(df["Maths"].mean(), inplace=True)
# /tmp/ipython-input-3432938247.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Science"].fillna(df["Science"].mean(), inplace=True)
# /tmp/ipython-input-3432938247.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["English"].fillna(df["English"].mean(), inplace=True)
#   Student  Maths  Science  English
# 0   Rohit  78.00     82.0     75.0
# 1    Amit  85.00     88.0     80.0
# 2   Sneha  75.25     94.0     85.0
# 3   Pooja  66.00     85.0     68.0
# 4   Rahul  72.00     76.0     77.0

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# Convert Data Types (if required)

# %%
df.dtypes
# Out:
# Student     object
# Maths      float64
# Science    float64
# English    float64
# dtype: object

# %% [markdown]
# Feature Engineering (New Columns)

# %%
df["Total"] = df["Maths"] + df["Science"] + df["English"]
df["Average"] = df["Total"] / 3

df
# Out:
#   Student  Maths  Science  English   Total    Average
# 0   Rohit  78.00     82.0     75.0  235.00  78.333333
# 1    Amit  85.00     88.0     80.0  253.00  84.333333
# 2   Sneha  75.25     94.0     85.0  254.25  84.750000
# 3   Pooja  66.00     85.0     68.0  219.00  73.000000
# 4   Rahul  72.00     76.0     77.0  225.00  75.000000

# %% [markdown]
# Convert Pandas Data → NumPy Array

# %%
marks_array = df[["Maths", "Science", "English"]].to_numpy()
marks_array
# Out:
# array([[78.  , 82.  , 75.  ],
#        [85.  , 88.  , 80.  ],
#        [75.25, 94.  , 85.  ],
#        [66.  , 85.  , 68.  ],
#        [72.  , 76.  , 77.  ]])

# %% [markdown]
# # **Data Analysis**

# %% [markdown]
# NumPy Calculations

# %%
class_average = np.mean(df["Average"])
highest_avg = np.max(df["Average"])
lowest_avg = np.min(df["Average"])

class_average, highest_avg, lowest_avg
# Out:
# (np.float64(79.08333333333333), 84.75, 73.0)

# %% [markdown]
# Identify Top Performer

# %%
top_student = df.loc[df["Average"].idxmax()]
top_student
# Out:
# Student     Sneha
# Maths       75.25
# Science      94.0
# English      85.0
# Total      254.25
# Average     84.75
# Name: 2, dtype: object

# %% [markdown]
# Pass / Fail Analysis

# %%
df["Result"] = np.where(df["Average"] >= 75, "Pass", "Fail")
df
# Out:
#   Student  Maths  Science  English   Total    Average Result
# 0   Rohit  78.00     82.0     75.0  235.00  78.333333   Pass
# 1    Amit  85.00     88.0     80.0  253.00  84.333333   Pass
# 2   Sneha  75.25     94.0     85.0  254.25  84.750000   Pass
# 3   Pooja  66.00     85.0     68.0  219.00  73.000000   Fail
# 4   Rahul  72.00     76.0     77.0  225.00  75.000000   Pass

# %% [markdown]
# Final Insights (For Explanation)

# %%
print("Class Average:", round(class_average, 2))
print("Top Student:", top_student["Student"])
print("Lowest Average:", round(lowest_avg, 2))
# Out:
# Class Average: 79.08
# Top Student: Sneha
# Lowest Average: 73.0
